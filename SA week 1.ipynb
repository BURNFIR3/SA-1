# %% [markdown]
# # SUMMER ANALYTICS 2024

# %% [markdown]
# # Week-1 Assignment

# %% [markdown]
# ![493179.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Data Grand Prix!**

# %% [markdown]
# **Welcome to your first assignment of Summer Analytics 2025! We hope you are excited to implement and test everything you have learnt up until now. The dataset which you'll use includes information about cars.**
#
# **We've got an interesting set of questions for you to get a basic understanding of pandas and data visualization libraries. GOOD LUCK!**
#
#
# ***Let's get started with importing numpy, pandas, seaborn and matplotlib!***
#
# Note - matplotlib should be imported with the command :
#
#  `import matplotlib.pyplot as plt`

# %% [markdown]
# ![image.avif](data:image/avif;base64,...)

# %% [markdown]
# **So lets get started!! Buckle up your belts for this exciting ride!!**

# %% [markdown]
# ### 1) Start by importing all important libraries
# For eg, "import numpy as np"

# %%
#your code here
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2) Read the csv file and assign it to a variable .

# %%
#your code here
df = pd.read_csv('cars.csv')

# %% [markdown]
# ### 3) Display shape of dataframe
# Expected Output - (398, 9)

# %%
#your code here
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #your code here
# ----> 2 df.shape
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### 4) Print all columns of dataframe
# Return an array containing names of all the columns.

# %%
#your code here
pd.array(df.columns) #one dimensional array of size 9
# Out:
# <NumpyExtensionArray>
# [         'mpg',    'cylinders', 'displacement',   'horsepower',
#        'weight', 'acceleration',   'model_year',       'origin',
#          'name']
# Length: 9, dtype: object

# %% [markdown]
# ### 6) Set the 'name' column as the index of dataframe

# %%
#your code here
df.index = df['name']
df
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0        86.0    2790
# vw pickup                  44.0          4          97.0        52.0    2130
# dodge rampage              32.0          4         135.0        84.0    2295
# ford ranger                28.0          4         120.0        79.0    2625
# chevy s-10                 31.0          4         119.0        82.0    2720
#
#                            acceleration  model_year  origin  \
# name
# chevrolet chevelle malibu          12.0          70     usa
# buick skylark 320                  11.5          70     usa
# plymouth satellite                 11.0          70     usa
# amc rebel sst                      12.0          70     usa
# ford torino                        10.5          70     usa
# ...                                 ...         ...     ...
# ford mustang gl                    15.6          82     usa
# vw pickup                          24.6          82  europe
# dodge rampage                      11.6          82     usa
# ford ranger                        18.6          82     usa
# chevy s-10                         19.4          82     usa
#
#                                                 name
# name
# chevrolet chevelle malibu  chevrolet chevelle malibu
# buick skylark 320                  buick skylark 320
# plymouth satellite                plymouth satellite
# amc rebel sst                          amc rebel sst
# ford torino                              ford torino
# ...                                              ...
# ford mustang gl                      ford mustang gl
# vw pickup                                  vw pickup
# dodge rampage                          dodge rampage
# ford ranger                              ford ranger
# chevy s-10                                chevy s-10
#
# [398 rows x 9 columns]

# %% [markdown]
# ###  7) Print a list of all the unique mpg values

# %%
#your code here
df['mpg'].unique().tolist()
# Out:
# [18.0,
#  15.0,
#  16.0,
#  17.0,
#  14.0,
#  24.0,
#  22.0,
#  21.0,
#  27.0,
#  26.0,
#  25.0,
#  10.0,
#  11.0,
#  9.0,
#  28.0,
#  19.0,
#  12.0,
#  13.0,
#  23.0,
#  30.0,
#  31.0,
#  35.0,
#  20.0,
#  29.0,
#  32.0,
#  33.0,
#  17.5,
#  15.5,
#  14.5,
#  22.5,
#  24.5,
#  18.5,
#  29.5,
#  26.5,
#  16.5,
#  31.5,
#  36.0,
#  25.5,
#  33.5,
#  20.5,
#  30.5,
#  21.5,
#  43.1,
#  36.1,
#  32.8,
#  39.4,
#  19.9,
#  19.4,
#  20.2,
#  19.2,
#  25.1,
#  20.6,
#  20.8,
#  18.6,
#  18.1,
#  17.7,
#  27.5,
#  27.2,
#  30.9,
#  21.1,
#  23.2,
#  23.8,
#  23.9,
#  20.3,
#  21.6,
#  16.2,
#  19.8,
#  22.3,
#  17.6,
#  18.2,
#  16.9,
#  31.9,
#  34.1,
#  35.7,
#  27.4,
#  25.4,
#  34.2,
#  34.5,
#  31.8,
#  37.3,
#  28.4,
#  28.8,
#  26.8,
#  41.5,
#  38.1,
#  32.1,
#  37.2,
#  26.4,
#  24.3,
#  19.1,
#  34.3,
#  29.8,
#  31.3,
#  37.0,
#  32.2,
#  46.6,
#  27.9,
#  40.8,
#  44.3,
#  43.4,
#  36.4,
#  44.6,
#  40.9,
#  33.8,
#  32.7,
#  23.7,
#  23.6,
#  32.4,
#  26.6,
#  25.8,
#  23.5,
#  39.1,
#  39.0,
#  35.1,
#  32.3,
#  37.7,
#  34.7,
#  34.4,
#  29.9,
#  33.7,
#  32.9,
#  31.6,
#  28.1,
#  30.7,
#  24.2,
#  22.4,
#  34.0,
#  38.0,
#  44.0]

# %% [markdown]
# ### 8) Create a column which contains the horsepower divided by weightas its metric and make this new column the index.

# %%
#your code here
df['hppw'] = df['horsepower']/df['weight'] #hppw = horsepower per weight😄
df.index = df['hppw']
#if you only want this column to be in index section only and not as a new column, then run
#df = df.drop(columns = ['hppw'])
df
# Out:
#            mpg  cylinders  displacement  horsepower  weight  acceleration  \
# hppw
# 0.037100  18.0          8         307.0       130.0    3504          12.0
# 0.044679  15.0          8         350.0       165.0    3693          11.5
# 0.043655  18.0          8         318.0       150.0    3436          11.0
# 0.043694  16.0          8         304.0       150.0    3433          12.0
# 0.040591  17.0          8         302.0       140.0    3449          10.5
# ...        ...        ...           ...         ...     ...           ...
# 0.030824  27.0          4         140.0        86.0    2790          15.6
# 0.024413  44.0          4          97.0        52.0    2130          24.6
# 0.036601  32.0          4         135.0        84.0    2295          11.6
# 0.030095  28.0          4         120.0        79.0    2625          18.6
# 0.030147  31.0          4         119.0        82.0    2720          19.4
#
#           model_year  origin                       name      hppw
# hppw
# 0.037100          70     usa  chevrolet chevelle malibu  0.037100
# 0.044679          70     usa          buick skylark 320  0.044679
# 0.043655          70     usa         plymouth satellite  0.043655
# 0.043694          70     usa              amc rebel sst  0.043694
# 0.040591          70     usa                ford torino  0.040591
# ...              ...     ...                        ...       ...
# 0.030824          82     usa            ford mustang gl  0.030824
# 0.024413          82  europe                  vw pickup  0.024413
# 0.036601          82     usa              dodge rampage  0.036601
# 0.030095          82     usa                ford ranger  0.030095
# 0.030147          82     usa                 chevy s-10  0.030147
#
# [398 rows x 10 columns]

# %% [markdown]
# ![OIP (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
#  **Checkpoint!!
# Congratulations on making it this far. You are really keeping up in Data Grand Prix.
# Now starts the real race i.e. graded questions of the quiz.**

# %% [markdown]
# ## GRADED Questions (To be answered in the quiz)
# ### Try to retrieve some information from the data and answer the questions below . BEST OF LUCK !!

# %% [markdown]
# ### 1. What is name of car that has the highest horsepower?

# %%
#your code here
df.iloc[df['horsepower'].argmax()]['name'] #can use loc aswell but name column has to be replaced with specific index
# Out:
# 'pontiac grand prix'

# %% [markdown]
# ### 2. How many cars have mpg ≥ 35?

# %%
#your code here
count = 0
for i in df['mpg']:
    if i >= 35:
        count+=1
print(count) #to check all the entries with >=35 mpg values, one could run df.sort_values('mpg').tail(count).
# Out:
# 36

# %% [markdown]
# ### 3. What is the most common origin for cars with horsepower > 100 and weight < 3000?

# %%
#your code here
df1 = df.loc[(df['horsepower'] > 100) & (df['weight'] < 3000)]
df1['origin'].mode() #this code can be shorten down to one line but is written in two for simplicity
# Out:
# 0    usa
# Name: origin, dtype: object

# %% [markdown]
# ### 4. What is the mean acceleration of cars from Japan? (rounded to 2 decimals)

# %%
#your code here
round(df.loc[df['origin'] == 'japan']['acceleration'].mean(),2) #I know, looks ugly
# Out:
# 16.17

# %% [markdown]
# ### 5. Which year had the highest average mpg?

# %%
#your code here
df2 = df.groupby(['model_year'])['mpg'].mean().sort_values(ascending = False)
df2.index[0]
# Out:
# 80

# %% [markdown]
# ## *Congratulations on coming this far! Since we were having so much fun playing with this dataset, let's move towards finish line by attempting some Ungraded questions!*
#
# ### **Note:** These questions are UNGRADED, and are given as an extra exercise.

# %% [markdown]
# ### Find the car (or cars) with the best ratio of horsepower to weight among all cars that also have above-median mpg.

# %%
#your code here
df1 = df.loc[df['mpg'] > df['mpg'].median()]
df1 = df1.reset_index(drop=True)
df1.loc[df1['hppw'].idxmax()]['name']
# Out:
# 'bmw 2002'

# %% [markdown]
# ### Design a multi-line plot using Matplotlib or Seaborn that shows the evolution of average mpg over the years, separately for each origin

# %%
#your code here
df = pd.read_csv('Cars.csv')
df1 = df.groupby(['origin', 'model_year'])['mpg'].mean().reset_index(name='average mpg')
sns.lineplot(data=df1, x='model_year', y='average mpg', hue='origin', hue_order=['japan', 'europe', 'usa'])
plt.show()

# %% [markdown]
# ### Create a Seaborn scatterplot (or PairGrid) where:
#
# X = horsepower
#
# Y = weight
#
# Color by: origin
#
# Size by: mpg
#
# Hue order = ['japan', 'europe', 'usa']
#
# Add meaningful plot titles and axis titles.

# %%
#your code here
sns.scatterplot(data=df, x='horsepower', y='weight', hue='origin', hue_order=['japan', 'europe', 'usa'])
plt.title('''Meaningful plot title
Specific power''') #Meaningful plot title.
plt.show()

# %% [markdown]
# ### We define a “consistent” car model as one that was produced over multiple years and had very low variation in mpg across those years (standard deviation < 1.0).
#
# Tasks:
#
# Identify car names that appear in more than one model_year.
#
# For each such name, compute the standard deviation of mpg across years.
#
# Return the car(s) with the lowest variation in mpg, among those with at least 2 appearances and std(mpg) < 1.0.
#
# Report the model name(s), number of appearances, and the average mpg.
#
# Bonus:
# Sort the result by number of appearances (descending), then mpg (descending).

# %%
#your code here
#car with lowest variation
df =pd.read_csv('cars.csv')
df1 = df.groupby('name')['mpg'].std()
df1 = df1.rename('mpgstd')
df2 = df['name'].value_counts()
df2 = df2.rename('appearances')
df3 = df.groupby('name')['mpg'].mean()
df3 = df3.rename('average mpg')
df5 = pd.merge(df2, df1, on='name')
df4 = pd.merge(df5, df3, on='name')
df4 = df4.loc[(df4['appearances'] >= 2) & (df4['mpgstd'] < 1.0)]
df4 = df4.sort_values(['appearances', 'mpgstd', 'average mpg'], ascending = [False, False, False])
df4.loc[df4['mpgstd'].idxmin()]
# Out:
# appearances     2.0
# mpgstd          0.0
# average mpg    27.0
# Name: datsun pl510, dtype: float64

# %%
#your code here
#Bonus
df4
# Out:
#                            appearances    mpgstd  average mpg
# name
# ford galaxie 500                     3  0.577350    14.333333
# plymouth fury iii                    3  0.577350    14.333333
# toyota corolla 1200                  2  0.707107    31.500000
# saab 99le                            2  0.707107    24.500000
# toyota mark ii                       2  0.707107    19.500000
# chevrolet chevelle malibu            2  0.707107    17.500000
# amc matador (sw)                     2  0.707107    14.500000
# ford gran torino (sw)                2  0.707107    13.500000
# ford ltd                             2  0.707107    13.500000
# volkswagen rabbit                    2  0.353553    29.250000
# dodge aspen                          2  0.353553    18.850000
# mazda 626                            2  0.212132    31.450000
# datsun pl510                         2  0.000000    27.000000

# %% [markdown]
# ![OIP.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Congratulations on completing the race. Kudos to you. Looking forward to meet you in next week.**
